# %% [markdown]
# # **HAND SIGN DETECTION - YOLO**
# ---
# ---

# %% [markdown]
# ## **Make the Default Storage for the next operation**

# %%
# Make the Default Storage for the next operation

import os
os.chdir('/content/drive/MyDrive/INeuron | Yolo/Hand Sign Prediction/')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ls
# Out:
# 'Hand Sign Detection.ipynb'   yolov5/

# %% [markdown]
# ## **Clone the GitHub Repository**

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# Upload our Images and Yaml Files

# Manually upload the Data Image folder from Laptop to yolov5 storage

# Data Image Folder contain 2 folder - train, test

# %%
# Next upload the yaml file

# %%
# Change the directory to Yolo5

os.chdir('yolov5')

# %%
# !ls
# Out:
# benchmarks.py	 data_images  LICENSE	       requirements.txt  tutorial.ipynb
# CITATION.cff	 data.yaml    models	       runs		 utils
# classify	 detect.py    __pycache__      segment		 val.py
# CONTRIBUTING.md  export.py    README.md        setup.cfg	 yolov5s.pt
# data		 hubconf.py   README.zh-CN.md  train.py

# %% [markdown]
# ## **Install Requirements from YOLOV5**

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.0/190.0 kB 4.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 617.3/617.3 kB 12.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## **Train Our Model with YOLOV5**

# %%
# !python train.py --data data.yaml --weights yolov5s.pt --img 416 --batch-size 8 --name Model  --epochs 50
# Out:
# train: weights=yolov5s.pt, cfg=, data=data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=8, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=Model, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# /bin/sh: 1: Yolo/Hand: not found
# fatal: cannot change to '/content/drive/My': No such file or directory
# YOLOv5 🚀 2023-10-3 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %% [markdown]
# ## **first, display our ground truth data**

# %%
from IPython.display import Image
print("GROUND TRUTH TRAINING DATA:")
Image(filename='/content/drive/MyDrive/INeuron | Yolo/Hand Sign Prediction/yolov5/runs/train/Model3/val_batch0_labels.jpg', width=900)
# Out:
# GROUND TRUTH TRAINING DATA:

# %% [markdown]
# ## **print out an augmented training example**

# %%
print("GROUND TRUTH AUGMENTED TRAINING DATA:")
Image(filename='/content/drive/MyDrive/INeuron | Yolo/Hand Sign Prediction/yolov5/runs/train/Model3/train_batch0.jpg', width=900)
# Out:
# GROUND TRUTH AUGMENTED TRAINING DATA:

# %%
# !python export.py --weights runs/train/Model5/weights/best.pt --include onnx --simplify --opset 12
# Out:
# export: data=data/coco128.yaml, weights=['runs/train/Model2/weights/best.pt'], imgsz=[640, 640], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=17, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['onnx']
# /bin/sh: 1: Yolo/Hand: not found
# fatal: cannot change to '/content/drive/MyDrive/INeuron': No such file or directory
# YOLOv5 🚀 2023-10-3 Python-3.10.12 torch-2.0.1+cu118 CPU
#
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/INeuron | Yolo/Hand Sign Prediction/yolov5/export.py", line 863, in <module>
#     main(opt)
#   File "/content/drive/MyDrive/INeuron | Yolo/Hand Sign Prediction/yolov5/export.py", line 858, in main
#     run(**vars(opt))
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py", line 115, in decorate_context
#     return func(*args, **kwargs)
# ...
